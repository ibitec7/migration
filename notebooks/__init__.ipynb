# %%
import polars as pl

# %%
df = pl.read_parquet("/home/ibrahim/Desktop/migration/data/processed/train_panel.parquet")

# %%
df
# Out:
# shape: (19_124, 29)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ country   ┆ month     ┆ visa_issu ┆ exchange_ ┆ … ┆ visa_lag_ ┆ exchange_ ┆ news_lag_ ┆ target_v │
# │ ---       ┆ ---       ┆ ances     ┆ rate      ┆   ┆ 6         ┆ lag_6     ┆ 6         ┆ isa_lead │
# │ str       ┆ date      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ _6       │
# │           ┆           ┆ i32       ┆ f64       ┆   ┆ i32       ┆ f64       ┆ u32       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Afghanist ┆ 2012-09-0 ┆ 0         ┆ null      ┆ … ┆ 0         ┆ null      ┆ 1         ┆ 0        │
# │ an        ┆ 1         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
